# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import style

# %%
df_main = pd.read_csv('C:\\Users\V_K\OneDrive\Documents\Pandas_Practice\\test.csv')
df = df_main
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
print(df.shape)
df = df.head(100)
df
# Out:
# (1459, 80)
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1   1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2   1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3   1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4   1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5   1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6   1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7   1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8   1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9   1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10  1471         120       RH         26.0     5858   Pave   NaN      IR1
# ...

# %%
df1 = df
per = df1.isnull().sum()/df1.shape[0] *100
per
# Out:
# Id                 0.0
# MSSubClass         0.0
# MSZoning           0.0
# LotFrontage       10.0
# LotArea            0.0
# Street             0.0
# Alley             87.0
# LotShape           0.0
# LandContour        0.0
# Utilities          0.0
# LotConfig          0.0
# LandSlope          0.0
# Neighborhood       0.0
# Condition1         0.0
# Condition2         0.0
# BldgType           0.0
# HouseStyle         0.0
# OverallQual        0.0
# OverallCond        0.0
# YearBuilt          0.0
# YearRemodAdd       0.0
# RoofStyle          0.0
# RoofMatl           0.0
# Exterior1st        0.0
# Exterior2nd        0.0
# MasVnrType         0.0
# MasVnrArea         0.0
# ExterQual          0.0
# ExterCond          0.0
# Foundation         0.0
# BsmtQual           0.0
# BsmtCond           0.0
# BsmtExposure       1.0
# BsmtFinType1       0.0
# BsmtFinSF1         0.0
# BsmtFinType2       0.0
# BsmtFinSF2         0.0
# BsmtUnfSF          0.0
# TotalBsmtSF        0.0
# Heating            0.0
# ...

# %%
clm_error = per[per >20].keys()
clm_error
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df_clean_20 = df1.drop(columns = clm_error)
df_clean_20
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0   1461          20       RH         80.0    11622   Pave      Reg
# 1   1462          20       RL         81.0    14267   Pave      IR1
# 2   1463          60       RL         74.0    13830   Pave      IR1
# 3   1464          60       RL         78.0     9978   Pave      IR1
# 4   1465         120       RL         43.0     5005   Pave      IR1
# 5   1466          60       RL         75.0    10000   Pave      IR1
# 6   1467          20       RL          NaN     7980   Pave      IR1
# 7   1468          60       RL         63.0     8402   Pave      IR1
# 8   1469          20       RL         85.0    10176   Pave      Reg
# 9   1470          20       RL         70.0     8400   Pave      Reg
# 10  1471         120       RH         26.0     5858   Pave      IR1
# 11  1472         160       RM         21.0     1680   Pave      Reg
# 12  1473         160       RM         21.0     1680   Pave      Reg
# ...

# %%
categaricalVar = df_clean_20['LotConfig'].unique()
categaricalVar
# Out:
# array(['Inside', 'Corner', 'FR2', 'CulDSac'], dtype=object)

# %%
df1[df1.loc[:,'LotConfig'] == 'Inside']
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1461          20       RH         80.0    11622   Pave   NaN      Reg
# 2   1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3   1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4   1465         120       RL         43.0     5005   Pave   NaN      IR1
# 6   1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7   1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8   1469          20       RL         85.0    10176   Pave   NaN      Reg
# 11  1472         160       RM         21.0     1680   Pave   NaN      Reg
# 12  1473         160       RM         21.0     1680   Pave   NaN      Reg
# 15  1476          60       RL        102.0    12858   Pave   NaN      IR1
# 17  1478          20       RL         90.0    11520   Pave   NaN      Reg
# 18  1479          20       RL         79.0    14122   Pave   NaN      IR1
# ...

# %%
df1.loc[:,'Alley'].isnull().sum()/df1.shape[0]*100
# Out:
# 87.0

# %%
df1[df1.loc[:,'LotConfig'] == 'Inside']['LotFrontage']  # This line collect the Valuse of 'LotFrontage'  corresponding to the 'Inside'
# Out:
# 0      80.0
# 2      74.0
# 3      78.0
# 4      43.0
# 6       NaN
# 7      63.0
# 8      85.0
# 11     21.0
# 12     21.0
# 15    102.0
# 17     90.0
# 18     79.0
# 19    110.0
# 21     41.0
# 23     43.0
# 24     67.0
# 25     63.0
# 27     73.0
# 28     92.0
# 30     70.0
# 33     85.0
# 34     88.0
# 36     39.0
# 37     30.0
# 38     24.0
# 39     24.0
# 42     57.0
# 43     68.0
# 44     80.0
# 45      NaN
# 46     80.0
# 47      NaN
# 48     80.0
# 49     80.0
# 51     88.0
# 52      NaN
# 53     98.0
# 54     68.0
# 56     75.0
# 58     70.0
# 59      NaN
# 60     87.0
# 61     80.0
# 62     60.0
# 63     60.0
# 65     70.0
# 67     60.0
# 69     80.0
# 71     56.0
# 72     69.0
# 74     69.0
# 75      NaN
# 76     68.0
# 78     50.0
# 79    100.0
# 80     60.0
# 83     50.0
# 84     50.0
# 85     50.0
# 87     50.0
# 88     52.0
# 89     52.0
# 90     51.0
# 91     57.0
# 92     60.0
# 93     52.0
# 94    100.0
# 95     72.0
# 96     60.0
# 97     65.0
# 98      NaN
# ...

# %%
value_Lot = df1[df1.loc[:,'LotConfig'] == 'Inside']['LotFrontage']
mean_Lot = np.mean(value_Lot)
mean_Lot
# Out:
# 65.921875

# %%
data_set_1= df1[df1.loc[:,'LotConfig'] == 'Inside']['LotFrontage'].replace (np.nan,mean_Lot)   # this line will replace the NaN value form the 'LotFrantAge' 
data_set_1
# Out:
# 0      80.000000
# 2      74.000000
# 3      78.000000
# 4      43.000000
# 6      65.921875
# 7      63.000000
# 8      85.000000
# 11     21.000000
# 12     21.000000
# 15    102.000000
# 17     90.000000
# 18     79.000000
# 19    110.000000
# 21     41.000000
# 23     43.000000
# 24     67.000000
# 25     63.000000
# 27     73.000000
# 28     92.000000
# 30     70.000000
# 33     85.000000
# 34     88.000000
# 36     39.000000
# 37     30.000000
# 38     24.000000
# 39     24.000000
# 42     57.000000
# 43     68.000000
# 44     80.000000
# 45     65.921875
# 46     80.000000
# 47     65.921875
# 48     80.000000
# 49     80.000000
# 51     88.000000
# 52     65.921875
# 53     98.000000
# 54     68.000000
# 56     75.000000
# 58     70.000000
# 59     65.921875
# 60     87.000000
# 61     80.000000
# 62     60.000000
# 63     60.000000
# 65     70.000000
# 67     60.000000
# 69     80.000000
# 71     56.000000
# 72     69.000000
# 74     69.000000
# 75     65.921875
# ...

# %%
data_set_1.isnull().sum()  # we can see there is no NaN value is Exist
# Out:
# 0

# %% [markdown]
# ## Same Task Cane be perform by the For Loop for diffrent element of list

# %%
lt = list(categaricalVar)
lt
# Out:
# ['Inside', 'Corner', 'FR2', 'CulDSac']

# %%
df1_copy=df1.copy()
for var_cls in df1['LotConfig'].unique():
    df1_copy.update(df1[df1.loc[:,'LotConfig'] == var_cls]['LotFrontage'].replace(np.nan,df1[df1.loc[:,'LotConfig'] == var_cls]['LotFrontage'].mean))

# %%
df1_copy.isnull().sum()/df1_copy.shape[0] *100
# Out:
# Id                 0.0
# MSSubClass         0.0
# MSZoning           0.0
# LotFrontage        0.0
# LotArea            0.0
# Street             0.0
# Alley             87.0
# LotShape           0.0
# LandContour        0.0
# Utilities          0.0
# LotConfig          0.0
# LandSlope          0.0
# Neighborhood       0.0
# Condition1         0.0
# Condition2         0.0
# BldgType           0.0
# HouseStyle         0.0
# OverallQual        0.0
# OverallCond        0.0
# YearBuilt          0.0
# YearRemodAdd       0.0
# RoofStyle          0.0
# RoofMatl           0.0
# Exterior1st        0.0
# Exterior2nd        0.0
# MasVnrType         0.0
# MasVnrArea         0.0
# ExterQual          0.0
# ExterCond          0.0
# Foundation         0.0
# BsmtQual           0.0
# BsmtCond           0.0
# BsmtExposure       1.0
# BsmtFinType1       0.0
# BsmtFinSF1         0.0
# BsmtFinType2       0.0
# BsmtFinSF2         0.0
# BsmtUnfSF          0.0
# TotalBsmtSF        0.0
# Heating            0.0
# ...

# %%
df1_copy=df1.copy()
num_var_miss = ['LotFrontage','MasVnrArea','GarageYrBlt']
cat_vars = ['LotConfig', 'MasVnrType', 'GarageType']

for LotConfig, num_var_miss in zip(cat_vars,num_var_miss ): 
    for var_cls in df1['LotConfig'].unique():
        df1_copy.update(df1[df1.loc[:,cat_vars] == var_cls][num_var_miss].replace(np.nan,df1[df1.loc[:,cat_vars] == var_cls][num_var_miss].mean))

# %%
df1_copy=df1.copy()
num_var_miss = ['LotFrontage','MasVnrArea','GarageYrBlt']
cat_vars = ['LotConfig', 'MasVnrType', 'YearRemodAdd']

for LotConfig, num_var_miss in zip(cat_vars,num_var_miss ): 
    for var_cls in df1['LotConfig'].unique():
        df1_copy.update(df1[df1.loc[:,cat_vars] == var_cls][num_var_miss].replace(np.nan,df1[df1.loc[:,cat_vars] == var_cls][num_var_miss].mean))
df1_copy
# Out:
#       Id  MSSubClass MSZoning  \
# 0   1461          20       RH
# 1   1462          20       RL
# 2   1463          60       RL
# 3   1464          60       RL
# 4   1465         120       RL
# 5   1466          60       RL
# 6   1467          20       RL
# 7   1468          60       RL
# 8   1469          20       RL
# 9   1470          20       RL
# 10  1471         120       RH
# 11  1472         160       RM
# 12  1473         160       RM
# 13  1474         160       RL
# 14  1475         120       RL
# 15  1476          60       RL
# 16  1477          20       RL
# 17  1478          20       RL
# 18  1479          20       RL
# 19  1480          20       RL
# 20  1481          60       RL
# 21  1482         120       RL
# 22  1483          20       RL
# 23  1484         120       RL
# 24  1485          80       RL
# 25  1486          60       RL
# 26  1487          60       RL
# 27  1488          20       RL
# 28  1489          20       FV
# 29  1490          20       FV
# ...

# %%
df1_copy.isnull().sum()    # Only listed columns['LotFrontage','MasVnrArea','GarageYrBlt']  are refine from the error 
per_3 = df1_copy.isnull().sum()/df1_copy.shape[0]*100
per_3
# Out:
# Id                 0.0
# MSSubClass         0.0
# MSZoning           0.0
# LotFrontage        0.0
# LotArea            0.0
# Street             0.0
# Alley             87.0
# LotShape           0.0
# LandContour        0.0
# Utilities          0.0
# LotConfig          0.0
# LandSlope          0.0
# Neighborhood       0.0
# Condition1         0.0
# Condition2         0.0
# BldgType           0.0
# HouseStyle         0.0
# OverallQual        0.0
# OverallCond        0.0
# YearBuilt          0.0
# YearRemodAdd       0.0
# RoofStyle          0.0
# RoofMatl           0.0
# Exterior1st        0.0
# Exterior2nd        0.0
# MasVnrType         0.0
# MasVnrArea         0.0
# ExterQual          0.0
# ExterCond          0.0
# Foundation         0.0
# BsmtQual           0.0
# BsmtCond           0.0
# BsmtExposure       1.0
# BsmtFinType1       0.0
# BsmtFinSF1         0.0
# BsmtFinType2       0.0
# BsmtFinSF2         0.0
# BsmtUnfSF          0.0
# TotalBsmtSF        0.0
# Heating            0.0
# ...

# %% [markdown]
# ### Data Distribution

# %%
lt = per_3[per_3>0].keys()
lt
# Out:
# Index(['Alley', 'BsmtExposure', 'KitchenQual', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df_int = df1_copy.select_dtypes(include = ['int64','float64'])


plt.figure(figsize =(12,40))
for i in range (len(lt)):
    plt.subplot(12,2,i+1)
    sns.histplot(df1_copy[lt[i]],color="k", label="100% Equities", kde=True, stat="density", linewidth=0.5)
    sns.histplot(df[lt[i]],color="y", label="100% Equities", kde=True, stat="density", linewidth=0.8)
# Out:
# C:\Users\V_K\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# C:\Users\V_K\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
df_int
# Out:
#       Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1461          20    11622            5            6       1961
# 1   1462          20    14267            6            6       1958
# 2   1463          60    13830            5            5       1997
# 3   1464          60     9978            6            6       1998
# 4   1465         120     5005            8            5       1992
# 5   1466          60    10000            6            5       1993
# 6   1467          20     7980            6            7       1992
# 7   1468          60     8402            6            5       1998
# 8   1469          20    10176            7            5       1990
# 9   1470          20     8400            4            5       1970
# 10  1471         120     5858            7            5       1999
# 11  1472         160     1680            6            5       1971
# 12  1473         160     1680            5            5       1971
# ...
